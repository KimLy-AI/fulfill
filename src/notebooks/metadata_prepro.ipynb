# %%
import pandas as pd

# %%
des_mt = pd.read_csv('../data/metadata/drive_des.csv')
pod_mt = pd.read_csv('../data/metadata/drive_pod.csv')
print(des_mt.shape)
print(pod_mt.shape)
# Out:
# (1132, 11)
# (18035, 11)

# %%
metadata = pd.concat([des_mt, pod_mt])
metadata.shape
# Out:
# (19167, 11)

# %%
metadata.head(10)
# Out:
#                                             filename file_extension  \
# 0                                   homebody đen.png           .png
# 1                               daddy homes 4551.png           .png
# 2  Troll_Co_Clothing_Working_Harder_Than_An_T-Shi...           .png
# 3  Limited Rod Wave Nostalgia Tour Sb Dunk Low Bl...           .png
# 4  LIV MORGAN TEE Wrestling Graphic Tee WWE Tee S...           .png
# 5  Sopula_Vintage_Saint_Cross_Graphics_Printed_Co...           .png
# 6  Paul Walker Shirt West Coast Choppers - trước ...           .png
# 7  Porsche Hoodie Porsche 911 GT3 RS Hoodie For M...           .png
# 8  Vintage Shirt Talladega Nights T-shirt Plain S...           .png
# 9                                1994 final four.png           .png
#
#   folder_name                                         folder_url  \
# 0        root  https://drive.google.com/drive/folders/1_NJA2-...
# 1        root  https://drive.google.com/drive/folders/1_NJA2-...
# ...
